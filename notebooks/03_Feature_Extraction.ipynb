# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/ItunuAjiboye/Tutorial_Host_Pathogen_Protein_Protein_Interaction_Prediction/blob/main/notebooks/03_Feature_Extraction.ipynb)
# > This notebook is designed to be run in Google Colab. Click on "Open in Colab" to continue.

# %% [markdown]
# #FEATURE EXTRACTION FOR HP-PPI PREDICTION
#
# Feature extraction is the process of converting protein sequences which are strings of amino acids into numerical vectors that machine learning models can understand. This step is necessary because classical machine learning
# algorithms cannot work directly with variable-length strings and require
# fixed-length numerical input. During this step, protein sequences of different lengths are transformed into fixed-length numerical representations that capture important biological properties of the protein.
#
# Several feature extraction methods have been developed to achieve this, and these descriptors can be applied individually or combined. Although combining multiple descriptors may improve the predictive performance of machine learning models, it increases computational time and memory requirements. Moreover, high-dimensional feature vectors can lead to overfitting and the inclusion of redundant or irrelevant features.
#
# In this tutorial, we will be using the iFeature package, a widely used Python-based toolkit for sequence feature extraction. iFeature  offers a wide range of descriptors and is user-friendy. This notebook
# demonstrates feature extraction using Amino Acid Composition (AAC) as a
# standalone descriptor, as well as a combined descriptor set consisting of
# Pseudo Amino Acid Composition (PAAC) and Conjoint Triad (CTriad), to
# illustrate both single-descriptor and multi-descriptor approaches within
# the same pipeline.
#
# ##Objectives of this notebook:
# By the end of this notebook, you will be able to:
# * Extract numerical features from both host and pathogen protein sequences
# * Apply descriptors individually or in combination to represent protein pairs.
# * Prepare the feature data for machine learning model training and evaluation

# %% [markdown]
# ##Amino Acid Composition

# %% [markdown]
# ### Module 1: Feature Extraction (Amino Acid Composition via iFeature)
#
# This module extracts Amino Acid Composition (AAC) features which is the relative
# frequency of each of the 20 standard amino acids in a protein sequence.
#
# **Important**: Feature extraction runs only ONCE. To avoid redundant computation and guarantee
# identical feature values across every ratio, this module extracts AAC from
# the master set of unique host and pathogen sequences produced during
# homology clustering (`CDHIT/master_clustering/host_proteins.fasta` and
# `pathogen_proteins.fasta`) from the previous notebook.
#
# **What this module does:**
# 1. Runs iFeature's AAC extraction via command line on the host and pathogen
#    FASTA files separately, producing one row per unique protein and one
#    column per amino acid (20 features each).
# 2. Renames the identifier column (`#`) to `host_protein_id` /
#    `pathogen_protein_id`, matching the ID convention used throughout the
#    rest of the pipeline.
# 3. Prefixes every feature column with `host_` or `pathogen_`, so host and
#    pathogen features never collide when later combined into a single
#    feature vector per interaction pair.
# 4. Validates that every protein in the resulting AAC table has a
#    corresponding entry in the homology cluster maps saved earlier — this
#    confirms the feature extraction and clustering steps used the exact
#    same protein universe, with no missing or mismatched proteins.

# %%
#Mounting Google Drive to access files
import os
from google.colab import drive
drive.mount ('/content/my_drive')

#import pandas for data manipulation
import pandas as pd

# %%
file_path = '/content/my_drive/My Drive/HPI/'

# %%
# !git clone https://github.com/Superzchen/iFeature.git

# %%
import os
import json
import pandas as pd


def extract_aac_cli(fasta_path, out_tsv_path, id_col_name, prefix, iFeature_script):
    """
    Runs iFeature's AAC extraction via CLI on a FASTA file, loads the
    resulting TSV, renames the ID column, and prefixes all feature columns.
    """
    cmd = f'python3 "{iFeature_script}" --file "{fasta_path}" --type AAC --out "{out_tsv_path}"'
    exit_code = os.system(cmd)

    if exit_code != 0 or not os.path.exists(out_tsv_path):
        raise RuntimeError(f"iFeature AAC extraction failed for {fasta_path} (exit code {exit_code})")

    aac_df = pd.read_csv(out_tsv_path, sep="\t")
    aac_df = aac_df.rename(columns={"#": id_col_name})
    aac_df = aac_df.rename(columns=lambda c: f"{prefix}_{c}" if c != id_col_name else c)

    print(f"[{prefix}] Extracted AAC: {aac_df.shape[0]} proteins, {aac_df.shape[1]-1} features")
    return aac_df


def validate_against_cluster_map(aac_df, id_col, cluster_map, label):
    """Confirms every protein in the AAC table has a corresponding cluster assignment."""
    missing = set(aac_df[id_col]) - set(cluster_map.keys())
    print(f"[{label}] proteins missing from cluster map: {len(missing)}")
    assert len(missing) == 0, f"Some {label} proteins in the AAC table have no cluster assignment!"
    assert len(aac_df) == len(cluster_map), f"{label} protein count mismatch between AAC table and cluster map!"
    print(f"[{label}] AAC table ({len(aac_df)}) matches cluster map ({len(cluster_map)}) exactly.")

# %%
base_hpi_path = "/content/my_drive/MyDrive/HPI"
master_fasta_dir = f"{base_hpi_path}/CDHIT/master_clustering"
master_features_dir = f"{base_hpi_path}/Features/master"

iFeature_script = "/content/iFeature/iFeature.py"
os.makedirs(master_features_dir, exist_ok=True)
os.chdir(master_features_dir)

host_fasta_path = os.path.join(master_fasta_dir, "host_proteins.fasta")
pathogen_fasta_path = os.path.join(master_fasta_dir, "pathogen_proteins.fasta")

print(os.path.exists(host_fasta_path), host_fasta_path)
print(os.path.exists(pathogen_fasta_path), pathogen_fasta_path)

host_aac_df = extract_aac_cli(
    fasta_path=host_fasta_path,
    out_tsv_path="host_aac.tsv",
    id_col_name="host_protein_id",
    prefix="host",
    iFeature_script=iFeature_script,
)
pathogen_aac_df = extract_aac_cli(
    fasta_path=pathogen_fasta_path,
    out_tsv_path="pathogen_aac.tsv",
    id_col_name="pathogen_protein_id",
    prefix="pathogen",
    iFeature_script=iFeature_script,
)

host_aac_df.to_csv("host_aac_renamed.csv", index=False)
pathogen_aac_df.to_csv("pathogen_aac_renamed.csv", index=False)

print(host_aac_df.shape, pathogen_aac_df.shape)

# --- Validate against the master cluster maps ---
with open(f"{master_fasta_dir}/host_cluster_map.json") as f:
    host_cluster_map = json.load(f)
with open(f"{master_fasta_dir}/pathogen_cluster_map.json") as f:
    pathogen_cluster_map = json.load(f)

validate_against_cluster_map(host_aac_df, "host_protein_id", host_cluster_map, label="host")
validate_against_cluster_map(pathogen_aac_df, "pathogen_protein_id", pathogen_cluster_map, label="pathogen")

# %% [markdown]
# ###Module 2: Feature Merging
#
# This module takes the AAC feature table extracted once in Module 1 and
# merges it into every dataset artifact produced in the previous notebook,
# for each imbalance ratio (1:1, 1:5, 1:10) independently:
#
# - The primary host-disjoint train/test split
# - All 10 cross-validation folds
# - Leave-One-Pathogen-Out (LOPO)
#
# **Output structure:** for each ratio, a mirrored `Features/<ratio>` directory
# is created containing feature-merged versions of every split (e.g.,
# `train_aac_split_features.csv`, `cv_folds/fold0_train_features.csv`,
# `lopo_folds_host_disjoint/lopo_bacillus_train_features.csv`)
#
# **Adapting to your own feature set:** this module makes no assumptions
# about which descriptor(s) were used to build the input feature tables. It
# only requires that `host_aac_df` and `pathogen_aac_df` contain a
# `host_protein_id` / `pathogen_protein_id` column plus any number of
# numeric feature columns. Swapping in a different descriptor, or a
# combination of several (e.g., AAC + DPC + CTD), requires no changes to
# this module at all.

# %%
def add_aac_features(df_split, host_aac_df, pathogen_aac_df):
    df_split = df_split.merge(host_aac_df, on="host_protein_id", how="left")
    df_split = df_split.merge(pathogen_aac_df, on="pathogen_protein_id", how="left")
    return df_split


def merge_features_for_ratio(cdhit_dir, features_dir, host_aac_df, pathogen_aac_df):
    os.makedirs(features_dir, exist_ok=True)

    # --- host-only train/test split ---
    train_df = pd.read_csv(f"{cdhit_dir}/train_split.csv")
    test_df = pd.read_csv(f"{cdhit_dir}/test_split.csv")
    train_df = add_aac_features(train_df, host_aac_df, pathogen_aac_df)
    test_df = add_aac_features(test_df, host_aac_df, pathogen_aac_df)
    train_df.to_csv(f"{features_dir}/train_aac_split_features.csv", index=False)
    test_df.to_csv(f"{features_dir}/test_aac_split_features.csv", index=False)
    print(f"[{features_dir}] host-only split: done")

    # --- 10-fold CV ---
    os.makedirs(f"{features_dir}/cv_folds", exist_ok=True)
    for fold in range(10):
        fold_train = pd.read_csv(f"{cdhit_dir}/cv_folds/fold{fold}_train.csv")
        fold_val = pd.read_csv(f"{cdhit_dir}/cv_folds/fold{fold}_val.csv")
        fold_train = add_aac_features(fold_train, host_aac_df, pathogen_aac_df)
        fold_val = add_aac_features(fold_val, host_aac_df, pathogen_aac_df)
        fold_train.to_csv(f"{features_dir}/cv_folds/fold{fold}_train_features.csv", index=False)
        fold_val.to_csv(f"{features_dir}/cv_folds/fold{fold}_val_features.csv", index=False)
    print(f"[{features_dir}] 10-fold CV: done")

    # --- LOPO  ---
    species_list = pd.concat([train_df, test_df])["pathogen_specie"].unique()

    os.makedirs(f"{features_dir}/lopo_folds", exist_ok=True)
    os.makedirs(f"{features_dir}/lopo_folds_host_disjoint", exist_ok=True)

    for sp in species_list:
        safe_name = str(sp).replace(" ", "_")


        lopo_train_hd = pd.read_csv(f"{cdhit_dir}/lopo_folds_host_disjoint/lopo_{safe_name}_train.csv")
        lopo_test_hd = pd.read_csv(f"{cdhit_dir}/lopo_folds_host_disjoint/lopo_{safe_name}_test.csv")
        lopo_train_hd = add_aac_features(lopo_train_hd, host_aac_df, pathogen_aac_df)
        lopo_test_hd = add_aac_features(lopo_test_hd, host_aac_df, pathogen_aac_df)
        lopo_train_hd.to_csv(f"{features_dir}/lopo_folds_host_disjoint/lopo_{safe_name}_train_features.csv", index=False)
        lopo_test_hd.to_csv(f"{features_dir}/lopo_folds_host_disjoint/lopo_{safe_name}_test_features.csv", index=False)

    print(f"[{features_dir}] LOPO: done")

# %%
# =============================================================================
# MERGE SEQUENCE FEATURES WITH DATA SPLITS
# =============================================================================

def add_sequence_features(df_split, host_features_df, pathogen_features_df):
    """
    Merge host and pathogen sequence features with an interaction dataset.
    """

    df_split = df_split.merge(
        host_features_df,
        on="host_protein_id",
        how="left"
    )

    df_split = df_split.merge(
        pathogen_features_df,
        on="pathogen_protein_id",
        how="left"
    )

    return df_split


def merge_features_for_ratio(
    cdhit_dir,
    features_dir,
    host_features_df,
    pathogen_features_df,
    feature_name="features"
):
    """
    Merge a specified feature set with the host-disjoint train/test split,
    10-fold cross-validation splits, and host-disjoint LOPO splits.
    """

    os.makedirs(features_dir, exist_ok=True)

    # =========================================================================
    # 1. HOST-DISJOINT TRAIN/TEST SPLIT
    # =========================================================================

    train_df = pd.read_csv(
        f"{cdhit_dir}/train_split.csv"
    )

    test_df = pd.read_csv(
        f"{cdhit_dir}/test_split.csv"
    )

    train_df = add_sequence_features(
        train_df,
        host_features_df,
        pathogen_features_df
    )

    test_df = add_sequence_features(
        test_df,
        host_features_df,
        pathogen_features_df
    )

    train_df.to_csv(
        f"{features_dir}/train_{feature_name}_split_features.csv",
        index=False
    )

    test_df.to_csv(
        f"{features_dir}/test_{feature_name}_split_features.csv",
        index=False
    )

    print(
        f"[{features_dir}] "
        f"Host-disjoint train/test split ({feature_name}): done"
    )


    # =========================================================================
    # 2. 10-FOLD CROSS-VALIDATION
    # =========================================================================

    cv_dir = f"{features_dir}/cv_folds"
    os.makedirs(cv_dir, exist_ok=True)

    for fold in range(10):

        fold_train = pd.read_csv(
            f"{cdhit_dir}/cv_folds/fold{fold}_train.csv"
        )

        fold_val = pd.read_csv(
            f"{cdhit_dir}/cv_folds/fold{fold}_val.csv"
        )

        fold_train = add_sequence_features(
            fold_train,
            host_features_df,
            pathogen_features_df
        )

        fold_val = add_sequence_features(
            fold_val,
            host_features_df,
            pathogen_features_df
        )

        fold_train.to_csv(
            f"{cv_dir}/fold{fold}_train_{feature_name}_features.csv",
            index=False
        )

        fold_val.to_csv(
            f"{cv_dir}/fold{fold}_val_{feature_name}_features.csv",
            index=False
        )

    print(
        f"[{features_dir}] "
        f"10-fold CV ({feature_name}): done"
    )


    # =========================================================================
    # 3. HOST-DISJOINT LOPO
    # =========================================================================

    species_list = pd.concat(
        [train_df, test_df]
    )["pathogen_specie"].unique()

    lopo_hd_dir = f"{features_dir}/lopo_folds_host_disjoint"
    os.makedirs(lopo_hd_dir, exist_ok=True)

    for sp in species_list:

        safe_name = str(sp).replace(" ", "_")

        lopo_train_hd = pd.read_csv(
            f"{cdhit_dir}/lopo_folds_host_disjoint/"
            f"lopo_{safe_name}_train.csv"
        )

        lopo_test_hd = pd.read_csv(
            f"{cdhit_dir}/lopo_folds_host_disjoint/"
            f"lopo_{safe_name}_test.csv"
        )

        lopo_train_hd = add_sequence_features(
            lopo_train_hd,
            host_features_df,
            pathogen_features_df
        )

        lopo_test_hd = add_sequence_features(
            lopo_test_hd,
            host_features_df,
            pathogen_features_df
        )

        lopo_train_hd.to_csv(
            f"{lopo_hd_dir}/"
            f"lopo_{safe_name}_train_{feature_name}_features.csv",
            index=False
        )

        lopo_test_hd.to_csv(
            f"{lopo_hd_dir}/"
            f"lopo_{safe_name}_test_{feature_name}_features.csv",
            index=False
        )

    print(
        f"[{features_dir}] "
        f"Host-disjoint LOPO ({feature_name}): done"
    )

# %% [markdown]
# Driver: merge for all three ratios

# %%
ratio_config = {
    1:  {"features_dir": f"{base_hpi_path}/Features/Balanced", "cdhit_dir": f"{base_hpi_path}/CDHIT/balanced_CDHIT"},
    5:  {"features_dir": f"{base_hpi_path}/Features/R5",       "cdhit_dir": f"{base_hpi_path}/CDHIT/R5_CDHIT"},
    10: {"features_dir": f"{base_hpi_path}/Features/R10",      "cdhit_dir": f"{base_hpi_path}/CDHIT/R10_CDHIT"},
}

for ratio, cfg in ratio_config.items():

    print(f"\n=== Ratio 1:{ratio} — merging AAC features ===")

    merge_features_for_ratio(
        cdhit_dir=cfg["cdhit_dir"],
        features_dir=cfg["features_dir"],
        host_features_df=host_aac_df,
        pathogen_features_df=pathogen_aac_df,
        feature_name="AAC"
    )

# %% [markdown]
# ##Generalised feature Extraction
# **To use a different or additional feature type** (e.g., dipeptide
# composition, CTD, pseudo-amino-acid composition), swap or extend the
# `descriptor` argument passed to iFeature's `--type` flag — the rest of the
# pipeline (validation, merging into splits, model training) requires no
# changes, since every downstream step only expects a protein-ID column plus
# some number of feature columns, regardless of which descriptor produced them.

# %%
def extract_feature_cli(fasta_path, out_tsv_path, id_col_name, prefix, descriptor, iFeature_script):
    """
    Runs any iFeature descriptor extraction via CLI on a FASTA file.

    descriptor : str
        e.g. "AAC", "DPC", "CTDC", "CTDT", "CTDD", "CTriad", "PAAC", "GAAC"
        must match iFeature's --type argument exactly.
    """
    cmd = f'python3 "{iFeature_script}" --file "{fasta_path}" --type {descriptor} --out "{out_tsv_path}"'
    exit_code = os.system(cmd)

    if exit_code != 0 or not os.path.exists(out_tsv_path):
        raise RuntimeError(f"iFeature {descriptor} extraction failed for {fasta_path} (exit code {exit_code})")

    feat_df = pd.read_csv(out_tsv_path, sep="\t")
    feat_df = feat_df.rename(columns={"#": id_col_name})
    feat_df = feat_df.rename(columns=lambda c: f"{prefix}_{descriptor}_{c}" if c != id_col_name else c)

    print(f"[{prefix}/{descriptor}] Extracted: {feat_df.shape[0]} proteins, {feat_df.shape[1]-1} features")
    return feat_df

# %% [markdown]
# ##Combined Features
# ### Feature Set: PAAC + Conjoint Triad (CTriad)
#
# In addition to Amino Acid Composition (AAC), this notebook demonstrates
# combining two additional sequence-based descriptors from iFeature:
#
# - **PAAC (Pseudo Amino Acid Composition):** extends simple amino acid
#   frequency with sequence-order information, capturing some of the local
#   patterning along a protein sequence rather than treating it as an
#   unordered "bag of amino acids." Requires sequences longer than its λ
#   (lambda) parameter (default 30), which the minimum sequence length
#   enforced during validation (35 residues) already satisfies.
# - **CTriad (Conjoint Triad):** groups amino acids into seven classes based
#   on shared physicochemical properties (e.g., volume, polarity), then
#   encodes the frequency of all possible three-residue class combinations
#   along the sequence. This captures short-range interaction patterns
#   between neighboring residues that AAC alone cannot represent.
#
# Both descriptors are extracted once, from the master set of unique host and
# pathogen sequences used in homology clustering, and combined into a single
# feature table per organism side (host and pathogen) before being merged
# into every train/test split, cross-validation fold, and LOPO fold across
# all three dataset ratios (1:1, 1:5, 1:10). This follows the same
# extract-once, merge-per-ratio pattern used for AAC.
#
# Feature columns are prefixed with both the organism (`host_`/`pathogen_`)
# and the descriptor name (`PAAC_`/`CTriad_`) to keep all feature sources
# distinguishable once combined into a single feature vector per interaction
# pair.

# %%
def extract_feature_cli(fasta_path, out_tsv_path, id_col_name, prefix, descriptor, iFeature_root):
    """
    Runs an iFeature descriptor extraction via CLI on a FASTA file.
    Works for any descriptor invoked via iFeature.py --type <descriptor>,
    e.g. "AAC", "PAAC", "CTriad".
    """
    cmd = f'python3 "{iFeature_root}/iFeature.py" --file "{fasta_path}" --type {descriptor} --out "{out_tsv_path}"'
    exit_code = os.system(cmd)

    if exit_code != 0 or not os.path.exists(out_tsv_path):
        raise RuntimeError(f"iFeature {descriptor} extraction failed for {fasta_path} (exit code {exit_code})")

    feat_df = pd.read_csv(out_tsv_path, sep="\t")
    feat_df = feat_df.rename(columns={"#": id_col_name})
    feat_df = feat_df.rename(columns=lambda c: f"{prefix}_{descriptor}_{c}" if c != id_col_name else c)

    print(f"[{prefix}/{descriptor}] Extracted: {feat_df.shape[0]} proteins, {feat_df.shape[1]-1} features")
    return feat_df


def extract_multiple_descriptors(fasta_path, id_col_name, prefix, descriptors, iFeature_root):
    combined = None
    for descriptor in descriptors:
        out_tsv = f"{prefix}_{descriptor}.tsv"
        feat_df = extract_feature_cli(fasta_path, out_tsv, id_col_name, prefix, descriptor, iFeature_root)
        combined = feat_df if combined is None else combined.merge(feat_df, on=id_col_name)
    return combined

# %%
iFeature_root = "/content/iFeature"

descriptors_to_use = ["PAAC", "CTriad"]

host_features_df = extract_multiple_descriptors(
    fasta_path=host_fasta_path,
    id_col_name="host_protein_id",
    prefix="host",
    descriptors=descriptors_to_use,
    iFeature_root=iFeature_root,
)

pathogen_features_df = extract_multiple_descriptors(
    fasta_path=pathogen_fasta_path,
    id_col_name="pathogen_protein_id",
    prefix="pathogen",
    descriptors=descriptors_to_use,
    iFeature_root=iFeature_root,
)

host_features_df.to_csv("host_features_combined.csv", index=False)
pathogen_features_df.to_csv("pathogen_features_combined.csv", index=False)

print(host_features_df.shape, pathogen_features_df.shape)

# %%
for ratio, cfg in ratio_config.items():

    print(f"\n=== Ratio 1:{ratio} — merging PAAC + CTriad features ===")

    merge_features_for_ratio(
        cdhit_dir=cfg["cdhit_dir"],
        features_dir=cfg["features_dir"],
        host_features_df=host_features_df,
        pathogen_features_df=pathogen_features_df,
        feature_name="PAAC_CTriad"
    )

# %% [markdown]
# ## **Adding a new feature combination**
#
# To use a different descriptor, or a different combination of descriptors,
# only one line needs to change as everything else in the pipeline (merging,
# splitting, model training) works unchanged, since it only expects a
# protein-ID column plus any number of numeric feature columns, regardless
# of which descriptor produced them.
#
# **Steps:**
#
# 1. Confirm the descriptor name matches iFeature's `--type` argument exactly
#    (e.g., `"DPC"`, `"CTDC"`, `"CTDT"`, `"CTDD"`, `"GAAC"`, `"QSOrder"`,
#    `"SOCNumber"`). Check `iFeature/codes/` for the full list of available
#    modules if unsure.
#
# 2. Update the `descriptors_to_use` list:
# ```python
#    descriptors_to_use = ["PAAC", "CTriad", "DPC"]   # add/remove as needed
# ```
#
# 3. Re-run the extraction and merging cells — `extract_multiple_descriptors`
#    will loop through every descriptor in the list, extract and prefix each
#    one, and merge them all into a single combined feature table per
#    organism side.

# %% [markdown]
# ## Conclusion
#
# At the end of this notebook, you have successfully extracted and prepared the relevant **features from the protein–protein interaction datasets** for machine learning. These extracted features provide the numerical representations required for training and evaluating predictive models.
#
# The resulting feature datasets are now ready for the next stage of the workflow: **model development and machine learning**.
